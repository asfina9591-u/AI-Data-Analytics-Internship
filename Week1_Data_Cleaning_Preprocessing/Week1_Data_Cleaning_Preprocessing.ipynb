# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/customer_churn.csv')

# %%
df.head()
# Out:
# Empty DataFrame
# ...

# %%
df.tail()
# Out:
# Empty DataFrame
# ...

# %%
df.shape
# Out:
# (0, 4452)

# %%
df.columns
# Out:
# Index(['{"cells":[{"cell_type":"markdown"', 'id:"stretch-davis"',
#        'metadata:{"_uuid":"1752ce061957fd1ce93d2e4db9494b7b29da7935"',
#        'papermill:{"duration":0.04692',
#        'end_time:"2021-05-07T08:35:59.190175"', 'exception:false',
#        'start_time:"2021-05-07T08:35:59.143255"', 'status:"completed"}',
#        'tags:[]}', 'source:["<center>\n"',
#        ...
#        'version:"2.3.2"}', 'kaggle:{"accelerator":"none"',
#        'dataSources:[{"sourceType":"datasetVersion"', 'sourceId:205932}]',
#        'isInternetEnabled:false', 'language:"python".1',
#        'sourceType:"notebook"', 'isGpuEnabled:false}}', 'nbformat:4',
#        'nbformat_minor:5}'],
#       dtype='object', length=4452)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Columns: 4452 entries, {"cells":[{"cell_type":"markdown" to nbformat_minor:5}
# dtypes: object(4452)
# memory usage: 132.0+ bytes

# %%
df.describe()
# Out:
#        {"cells":[{"cell_type":"markdown" id:"stretch-davis"  \
# count                                  0                  0
# unique                                 0                  0
# top                                  NaN                NaN
# freq                                 NaN                NaN
#
#        metadata:{"_uuid":"1752ce061957fd1ce93d2e4db9494b7b29da7935"  \
# count                                                   0
# unique                                                  0
# top                                                   NaN
# freq                                                  NaN
#
#        papermill:{"duration":0.04692 end_time:"2021-05-07T08:35:59.190175"  \
# count                              0                                     0
# unique                             0                                     0
# top                              NaN                                   NaN
# ...

# %%
df.isnull().sum()
# Out:
# {"cells":[{"cell_type":"markdown"                               0
# id:"stretch-davis"                                              0
# metadata:{"_uuid":"1752ce061957fd1ce93d2e4db9494b7b29da7935"    0
# papermill:{"duration":0.04692                                   0
# end_time:"2021-05-07T08:35:59.190175"                           0
#                                                                ..
# language:"python".1                                             0
# sourceType:"notebook"                                           0
# isGpuEnabled:false}}                                            0
# nbformat:4                                                      0
# nbformat_minor:5}                                               0
# Length: 4452, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Gender'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1216/3880930599.py in <cell line: 0>()
# ----> 1 df['Gender'].unique()
#
# ...

# %%
df.dtypes
# Out:
# {"cells":[{"cell_type":"markdown"                               object
# id:"stretch-davis"                                              object
# metadata:{"_uuid":"1752ce061957fd1ce93d2e4db9494b7b29da7935"    object
# papermill:{"duration":0.04692                                   object
# end_time:"2021-05-07T08:35:59.190175"                           object
#                                                                  ...
# language:"python".1                                             object
# sourceType:"notebook"                                           object
# isGpuEnabled:false}}                                            object
# nbformat:4                                                      object
# nbformat_minor:5}                                               object
# Length: 4452, dtype: object

# %%
df.dtypes
# Out:
# {"cells":[{"cell_type":"markdown"                               object
# id:"stretch-davis"                                              object
# metadata:{"_uuid":"1752ce061957fd1ce93d2e4db9494b7b29da7935"    object
# papermill:{"duration":0.04692                                   object
# end_time:"2021-05-07T08:35:59.190175"                           object
#                                                                  ...
# language:"python".1                                             object
# sourceType:"notebook"                                           object
# isGpuEnabled:false}}                                            object
# nbformat:4                                                      object
# nbformat_minor:5}                                               object
# Length: 4452, dtype: object

# %%
print(df.columns.tolist())
# Out:
# ['{"cells":[{"cell_type":"markdown"', 'id:"stretch-davis"', 'metadata:{"_uuid":"1752ce061957fd1ce93d2e4db9494b7b29da7935"', 'papermill:{"duration":0.04692', 'end_time:"2021-05-07T08:35:59.190175"', 'exception:false', 'start_time:"2021-05-07T08:35:59.143255"', 'status:"completed"}', 'tags:[]}', 'source:["<center>\\n"', '<img src=\\https://habrastorage.org/webt/ia/m9/zk/iam9zkyzqebnf_okxipihkgjwnw.jpeg\\">\\n"', '    \\n', '## [mlcourse.ai](https://mlcourse.ai) – Open Machine Learning Course \\n', '\\n', 'Author: [Yury Kashnitsky](https://yorko.github.io). Translated and edited by [Christina Butsko](https://www.linkedin.com/in/christinabutsko/), [Yuanyuan Pao](https://www.linkedin.com/in/yuanyuanpao/), [Anastasia Manokhina](https://www.linkedin.com/in/anastasiamanokhina), Sergey Isaev, and [Artem Trunov](https://www.linkedin.com/in/datamove/). This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0
# ...

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns.tolist())
# Out:
# ['{"cells":[{"cell_type":"markdown"', 'id:"stretch-davis"', 'metadata:{"_uuid":"1752ce061957fd1ce93d2e4db9494b7b29da7935"', 'papermill:{"duration":0.04692', 'end_time:"2021-05-07T08:35:59.190175"', 'exception:false', 'start_time:"2021-05-07T08:35:59.143255"', 'status:"completed"}', 'tags:[]}', 'source:["<center>\\n"', '<img src=\\https://habrastorage.org/webt/ia/m9/zk/iam9zkyzqebnf_okxipihkgjwnw.jpeg\\">\\n"', '\\n', '## [mlcourse.ai](https://mlcourse.ai) – Open Machine Learning Course \\n', '\\n', 'Author: [Yury Kashnitsky](https://yorko.github.io). Translated and edited by [Christina Butsko](https://www.linkedin.com/in/christinabutsko/), [Yuanyuan Pao](https://www.linkedin.com/in/yuanyuanpao/), [Anastasia Manokhina](https://www.linkedin.com/in/anastasiamanokhina), Sergey Isaev, and [Artem Trunov](https://www.linkedin.com/in/datamove/). This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/) l
# ...

# %%
df.columns = df.columns.str.strip()      # remove spaces
df.columns = df.columns.str.replace(' ', '_')  # replace spaces with underscores

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# index.pyx in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'TotalCharges'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1216/1383647473.py in <cell line: 0>()
# ...

# %%
print(df.columns.tolist())
# Out:
# ['{"cells":[{"cell_type":"markdown"', 'id:"stretch-davis"', 'metadata:{"_uuid":"1752ce061957fd1ce93d2e4db9494b7b29da7935"', 'papermill:{"duration":0.04692', 'end_time:"2021-05-07T08:35:59.190175"', 'exception:false', 'start_time:"2021-05-07T08:35:59.143255"', 'status:"completed"}', 'tags:[]}', 'source:["<center>\\n"', '<img_src=\\https://habrastorage.org/webt/ia/m9/zk/iam9zkyzqebnf_okxipihkgjwnw.jpeg\\">\\n"', '\\n', '##_[mlcourse.ai](https://mlcourse.ai)_–_Open_Machine_Learning_Course_\\n', '\\n', 'Author:_[Yury_Kashnitsky](https://yorko.github.io)._Translated_and_edited_by_[Christina_Butsko](https://www.linkedin.com/in/christinabutsko/),_[Yuanyuan_Pao](https://www.linkedin.com/in/yuanyuanpao/),_[Anastasia_Manokhina](https://www.linkedin.com/in/anastasiamanokhina),_Sergey_Isaev,_and_[Artem_Trunov](https://www.linkedin.com/in/datamove/)._This_material_is_subject_to_the_terms_and_conditions_of_the_[Creative_Commons_CC_BY-NC-SA_4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/)_l
# ...

# %%
df.columns = df.columns.str.strip()   # remove leading/trailing spaces

# %%
df.columns = df.columns.str.replace(' ', '_')  # replace spaces with underscores

# %%
print(df.columns.tolist())
# Out:
# ['{"cells":[{"cell_type":"markdown"', 'id:"stretch-davis"', 'metadata:{"_uuid":"1752ce061957fd1ce93d2e4db9494b7b29da7935"', 'papermill:{"duration":0.04692', 'end_time:"2021-05-07T08:35:59.190175"', 'exception:false', 'start_time:"2021-05-07T08:35:59.143255"', 'status:"completed"}', 'tags:[]}', 'source:["<center>\\n"', '<img_src=\\https://habrastorage.org/webt/ia/m9/zk/iam9zkyzqebnf_okxipihkgjwnw.jpeg\\">\\n"', '\\n', '##_[mlcourse.ai](https://mlcourse.ai)_–_Open_Machine_Learning_Course_\\n', '\\n', 'Author:_[Yury_Kashnitsky](https://yorko.github.io)._Translated_and_edited_by_[Christina_Butsko](https://www.linkedin.com/in/christinabutsko/),_[Yuanyuan_Pao](https://www.linkedin.com/in/yuanyuanpao/),_[Anastasia_Manokhina](https://www.linkedin.com/in/anastasiamanokhina),_Sergey_Isaev,_and_[Artem_Trunov](https://www.linkedin.com/in/datamove/)._This_material_is_subject_to_the_terms_and_conditions_of_the_[Creative_Commons_CC_BY-NC-SA_4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/)_l
# ...

# %%
print(df.columns.tolist())
# Out:
# ['{"cells":[{"cell_type":"markdown"', 'id:"stretch-davis"', 'metadata:{"_uuid":"1752ce061957fd1ce93d2e4db9494b7b29da7935"', 'papermill:{"duration":0.04692', 'end_time:"2021-05-07T08:35:59.190175"', 'exception:false', 'start_time:"2021-05-07T08:35:59.143255"', 'status:"completed"}', 'tags:[]}', 'source:["<center>\\n"', '<img_src=\\https://habrastorage.org/webt/ia/m9/zk/iam9zkyzqebnf_okxipihkgjwnw.jpeg\\">\\n"', '\\n', '##_[mlcourse.ai](https://mlcourse.ai)_–_Open_Machine_Learning_Course_\\n', '\\n', 'Author:_[Yury_Kashnitsky](https://yorko.github.io)._Translated_and_edited_by_[Christina_Butsko](https://www.linkedin.com/in/christinabutsko/),_[Yuanyuan_Pao](https://www.linkedin.com/in/yuanyuanpao/),_[Anastasia_Manokhina](https://www.linkedin.com/in/anastasiamanokhina),_Sergey_Isaev,_and_[Artem_Trunov](https://www.linkedin.com/in/datamove/)._This_material_is_subject_to_the_terms_and_conditions_of_the_[Creative_Commons_CC_BY-NC-SA_4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/)_l
# ...

# %%
for i, col in enumerate(df.columns):
    print(i, repr(col))
# Out:
# 0 '{"cells":[{"cell_type":"markdown"'
# 1 'id:"stretch-davis"'
# 2 'metadata:{"_uuid":"1752ce061957fd1ce93d2e4db9494b7b29da7935"'
# 3 'papermill:{"duration":0.04692'
# 4 'end_time:"2021-05-07T08:35:59.190175"'
# 5 'exception:false'
# 6 'start_time:"2021-05-07T08:35:59.143255"'
# 7 'status:"completed"}'
# 8 'tags:[]}'
# 9 'source:["<center>\\n"'
# 10 '<img_src=\\https://habrastorage.org/webt/ia/m9/zk/iam9zkyzqebnf_okxipihkgjwnw.jpeg\\">\\n"'
# 11 '\\n'
# 12 '##_[mlcourse.ai](https://mlcourse.ai)_–_Open_Machine_Learning_Course_\\n'
# 13 '\\n'
# ...

# %%
print(df.columns.tolist())
# Out:
# ['{"cells":[{"cell_type":"markdown"', 'id:"stretch-davis"', 'metadata:{"_uuid":"1752ce061957fd1ce93d2e4db9494b7b29da7935"', 'papermill:{"duration":0.04692', 'end_time:"2021-05-07T08:35:59.190175"', 'exception:false', 'start_time:"2021-05-07T08:35:59.143255"', 'status:"completed"}', 'tags:[]}', 'source:["<center>\\n"', '<img_src=\\https://habrastorage.org/webt/ia/m9/zk/iam9zkyzqebnf_okxipihkgjwnw.jpeg\\">\\n"', '\\n', '##_[mlcourse.ai](https://mlcourse.ai)_–_Open_Machine_Learning_Course_\\n', '\\n', 'Author:_[Yury_Kashnitsky](https://yorko.github.io)._Translated_and_edited_by_[Christina_Butsko](https://www.linkedin.com/in/christinabutsko/),_[Yuanyuan_Pao](https://www.linkedin.com/in/yuanyuanpao/),_[Anastasia_Manokhina](https://www.linkedin.com/in/anastasiamanokhina),_Sergey_Isaev,_and_[Artem_Trunov](https://www.linkedin.com/in/datamove/)._This_material_is_subject_to_the_terms_and_conditions_of_the_[Creative_Commons_CC_BY-NC-SA_4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/)_l
# ...

# %%
import os

print(os.listdir('/content'))
# Out:
# ['.config', '.ipynb_checkpoints', 'customer_churn.csv', 'sample_data']

# %%
df = pd.read_csv('/content/customer_churn.csv')

# %%
df.head()
# Out:
# Empty DataFrame
# ...

# %%
print(df.columns.tolist())
# Out:
# ['{"cells":[{"cell_type":"markdown"', 'id:"stretch-davis"', 'metadata:{"_uuid":"1752ce061957fd1ce93d2e4db9494b7b29da7935"', 'papermill:{"duration":0.04692', 'end_time:"2021-05-07T08:35:59.190175"', 'exception:false', 'start_time:"2021-05-07T08:35:59.143255"', 'status:"completed"}', 'tags:[]}', 'source:["<center>\\n"', '<img src=\\https://habrastorage.org/webt/ia/m9/zk/iam9zkyzqebnf_okxipihkgjwnw.jpeg\\">\\n"', '    \\n', '## [mlcourse.ai](https://mlcourse.ai) – Open Machine Learning Course \\n', '\\n', 'Author: [Yury Kashnitsky](https://yorko.github.io). Translated and edited by [Christina Butsko](https://www.linkedin.com/in/christinabutsko/), [Yuanyuan Pao](https://www.linkedin.com/in/yuanyuanpao/), [Anastasia Manokhina](https://www.linkedin.com/in/anastasiamanokhina), Sergey Isaev, and [Artem Trunov](https://www.linkedin.com/in/datamove/). This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0
# ...

# %%
print("Shape:", df.shape)
# Out:
# Shape: (0, 4452)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Columns: 4452 entries, {"cells":[{"cell_type":"markdown" to nbformat_minor:5}
# dtypes: object(4452)
# memory usage: 132.0+ bytes

# %%
df.describe()
# Out:
#        {"cells":[{"cell_type":"markdown" id:"stretch-davis"  \
# count                                  0                  0
# unique                                 0                  0
# top                                  NaN                NaN
# freq                                 NaN                NaN
#
#        metadata:{"_uuid":"1752ce061957fd1ce93d2e4db9494b7b29da7935"  \
# count                                                   0
# unique                                                  0
# top                                                   NaN
# freq                                                  NaN
#
#        papermill:{"duration":0.04692 end_time:"2021-05-07T08:35:59.190175"  \
# count                              0                                     0
# unique                             0                                     0
# top                              NaN                                   NaN
# ...

# %%
df.isnull().sum()
# Out:
# {"cells":[{"cell_type":"markdown"                               0
# id:"stretch-davis"                                              0
# metadata:{"_uuid":"1752ce061957fd1ce93d2e4db9494b7b29da7935"    0
# papermill:{"duration":0.04692                                   0
# end_time:"2021-05-07T08:35:59.190175"                           0
#                                                                ..
# language:"python".1                                             0
# sourceType:"notebook"                                           0
# isGpuEnabled:false}}                                            0
# nbformat:4                                                      0
# nbformat_minor:5}                                               0
# Length: 4452, dtype: int64

# %%
import os

print(os.listdir('/content'))
# Out:
# ['.config', '.ipynb_checkpoints', 'archive (1).zip', 'sample_data']

# %%
import zipfile
import os

zip_path = '/content/archive (1).zip'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('/content/dataset')

print("Files extracted:")
print(os.listdir('/content/dataset'))
# Out:
# Files extracted:
# ['Telco_customer_churn.xlsx']

# %%
import os

for root, dirs, files in os.walk('/content/dataset'):
    for file in files:
        print(os.path.join(root, file))
# Out:
# /content/dataset/Telco_customer_churn.xlsx

# %%
import zipfile

zip_path = '/content/archive (1).zip'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    print("Files inside the ZIP:")
    for file in zip_ref.namelist():
        print(file)
# Out:
# Files inside the ZIP:
# Telco_customer_churn.xlsx

# %%
import zipfile

zip_path = '/content/archive (1).zip'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('/content/dataset')

print("Extracted successfully!")
# Out:
# Extracted successfully!

# %%
import os

print(os.listdir('/content/dataset'))
# Out:
# ['Telco_customer_churn.xlsx']

# %%
import pandas as pd

df = pd.read_excel('/content/dataset/Telco_customer_churn.xlsx')

# %%
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %%
print("Shape:", df.shape)
# Out:
# Shape: (7043, 33)

# %%
print(df.columns.tolist())
# Out:
# ['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code', 'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Tenure Months', 'Phone Service', 'Multiple Lines', 'Internet Service', 'Online Security', 'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value', 'Churn Score', 'CLTV', 'Churn Reason']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
df.describe()
# Out:
#         Count      Zip Code     Latitude    Longitude  Tenure Months  \
# count  7043.0   7043.000000  7043.000000  7043.000000    7043.000000
# mean      1.0  93521.964646    36.282441  -119.798880      32.371149
# std       0.0   1865.794555     2.455723     2.157889      24.559481
# min       1.0  90001.000000    32.555828  -124.301372       0.000000
# 25%       1.0  92102.000000    34.030915  -121.815412       9.000000
# 50%       1.0  93552.000000    36.391777  -119.730885      29.000000
# 75%       1.0  95351.000000    38.224869  -118.043237      55.000000
# max       1.0  96161.000000    41.962127  -114.192901      72.000000
#
#        Monthly Charges  Churn Value  Churn Score         CLTV
# count      7043.000000  7043.000000  7043.000000  7043.000000
# mean         64.761692     0.265370    58.699418  4400.295755
# std          30.090047     0.441561    21.525131  1183.057152
# min          18.250000     0.000000     5.000000  2003.000000
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges           0
# Churn Label             0
# Churn Value             0
# Churn Score             0
# CLTV                    0
# Churn Reason         5174
# dtype: int64

# %%
missing_count = df.isnull().sum()

missing_percentage = (missing_count / len(df)) * 100

missing_table = pd.DataFrame({
    'Missing Values': missing_count,
    'Percentage': missing_percentage
})

missing_table
# Out:
#                    Missing Values  Percentage
# CustomerID                      0    0.000000
# Count                           0    0.000000
# Country                         0    0.000000
# State                           0    0.000000
# City                            0    0.000000
# Zip Code                        0    0.000000
# Lat Long                        0    0.000000
# Latitude                        0    0.000000
# Longitude                       0    0.000000
# Gender                          0    0.000000
# Senior Citizen                  0    0.000000
# Partner                         0    0.000000
# Dependents                      0    0.000000
# Tenure Months                   0    0.000000
# Phone Service                   0    0.000000
# Multiple Lines                  0    0.000000
# Internet Service                0    0.000000
# Online Security                 0    0.000000
# Online Backup                   0    0.000000
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 1869  7590-VHVEG      1  United States  California   Los Angeles     90001
# 1870  5575-GNVDE      1  United States  California   Los Angeles     90002
# 1871  7795-CFOCW      1  United States  California   Los Angeles     90004
# 1872  1452-KIOVK      1  United States  California   Los Angeles     90007
# 1873  6713-OKOMC      1  United States  California   Los Angeles     90008
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# ...

# %%
(df == '').sum()
# Out:
# CustomerID           0
# Count                0
# Country              0
# State                0
# City                 0
# Zip Code             0
# Lat Long             0
# Latitude             0
# Longitude            0
# Gender               0
# Senior Citizen       0
# Partner              0
# Dependents           0
# Tenure Months        0
# Phone Service        0
# Multiple Lines       0
# Internet Service     0
# Online Security      0
# Online Backup        0
# Device Protection    0
# Tech Support         0
# Streaming TV         0
# Streaming Movies     0
# Contract             0
# Paperless Billing    0
# Payment Method       0
# Monthly Charges      0
# Total Charges        0
# Churn Label          0
# Churn Value          0
# Churn Score          0
# CLTV                 0
# Churn Reason         0
# dtype: int64

# %%
(df == ' ').sum()
# Out:
# CustomerID            0
# Count                 0
# Country               0
# State                 0
# City                  0
# Zip Code              0
# Lat Long              0
# Latitude              0
# Longitude             0
# Gender                0
# Senior Citizen        0
# Partner               0
# Dependents            0
# Tenure Months         0
# Phone Service         0
# Multiple Lines        0
# Internet Service      0
# Online Security       0
# Online Backup         0
# Device Protection     0
# Tech Support          0
# Streaming TV          0
# Streaming Movies      0
# Contract              0
# Paperless Billing     0
# Payment Method        0
# Monthly Charges       0
# Total Charges        11
# Churn Label           0
# Churn Value           0
# Churn Score           0
# CLTV                  0
# Churn Reason          0
# dtype: int64

# %%
df.dtypes
# Out:
# CustomerID            object
# Count                  int64
# Country               object
# State                 object
# City                  object
# Zip Code               int64
# Lat Long              object
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure Months          int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges         object
# Churn Label           object
# Churn Value            int64
# Churn Score            int64
# CLTV                   int64
# ...

# %%
print(df.columns.tolist())
# Out:
# ['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code', 'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Tenure Months', 'Phone Service', 'Multiple Lines', 'Internet Service', 'Online Security', 'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value', 'Churn Score', 'CLTV', 'Churn Reason']

# %%
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges           0
# Churn Label             0
# Churn Value             0
# Churn Score             0
# CLTV                    0
# Churn Reason         5174
# dtype: int64

# %%
missing_count = df.isnull().sum()

missing_percentage = (missing_count / len(df)) * 100

missing_table = pd.DataFrame({
    'Missing Values': missing_count,
    'Percentage': missing_percentage
})

missing_table
# Out:
#                    Missing Values  Percentage
# CustomerID                      0    0.000000
# Count                           0    0.000000
# Country                         0    0.000000
# State                           0    0.000000
# City                            0    0.000000
# Zip Code                        0    0.000000
# Lat Long                        0    0.000000
# Latitude                        0    0.000000
# Longitude                       0    0.000000
# Gender                          0    0.000000
# Senior Citizen                  0    0.000000
# Partner                         0    0.000000
# Dependents                      0    0.000000
# Tenure Months                   0    0.000000
# Phone Service                   0    0.000000
# Multiple Lines                  0    0.000000
# Internet Service                0    0.000000
# Online Security                 0    0.000000
# Online Backup                   0    0.000000
# ...

# %%
missing_table[missing_table['Missing Values'] > 0]
# Out:
#               Missing Values  Percentage
# Churn Reason            5174   73.463013

# %%
df[df.isnull().any(axis=1)].head(20)
# Out:
#       CustomerID  Count        Country       State         City  Zip Code  \
# 1869  7590-VHVEG      1  United States  California  Los Angeles     90001
# 1870  5575-GNVDE      1  United States  California  Los Angeles     90002
# 1871  7795-CFOCW      1  United States  California  Los Angeles     90004
# 1872  1452-KIOVK      1  United States  California  Los Angeles     90007
# 1873  6713-OKOMC      1  United States  California  Los Angeles     90008
# 1874  6388-TABGU      1  United States  California  Los Angeles     90011
# 1875  9763-GRSKD      1  United States  California  Los Angeles     90012
# 1876  7469-LKBCI      1  United States  California  Los Angeles     90013
# 1877  8091-TTVAX      1  United States  California  Los Angeles     90014
# 1878  5129-JLPIS      1  United States  California  Los Angeles     90016
# 1879  3655-SNQYZ      1  United States  California  Los Angeles     90017
# 1880  8191-XWSZG      1  United States  California  Los Angeles     90018
# ...

# %%
(df == '').sum()
# Out:
# CustomerID           0
# Count                0
# Country              0
# State                0
# City                 0
# Zip Code             0
# Lat Long             0
# Latitude             0
# Longitude            0
# Gender               0
# Senior Citizen       0
# Partner              0
# Dependents           0
# Tenure Months        0
# Phone Service        0
# Multiple Lines       0
# Internet Service     0
# Online Security      0
# Online Backup        0
# Device Protection    0
# Tech Support         0
# Streaming TV         0
# Streaming Movies     0
# Contract             0
# Paperless Billing    0
# Payment Method       0
# Monthly Charges      0
# Total Charges        0
# Churn Label          0
# Churn Value          0
# Churn Score          0
# CLTV                 0
# Churn Reason         0
# dtype: int64

# %%
(df == ' ').sum()
# Out:
# CustomerID            0
# Count                 0
# Country               0
# State                 0
# City                  0
# Zip Code              0
# Lat Long              0
# Latitude              0
# Longitude             0
# Gender                0
# Senior Citizen        0
# Partner               0
# Dependents            0
# Tenure Months         0
# Phone Service         0
# Multiple Lines        0
# Internet Service      0
# Online Security       0
# Online Backup         0
# Device Protection     0
# Tech Support          0
# Streaming TV          0
# Streaming Movies      0
# Contract              0
# Paperless Billing     0
# Payment Method        0
# Monthly Charges       0
# Total Charges        11
# Churn Label           0
# Churn Value           0
# Churn Score           0
# CLTV                  0
# Churn Reason          0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges           0
# Churn Label             0
# Churn Value             0
# Churn Score             0
# CLTV                    0
# Churn Reason         5174
# dtype: int64

# %%
missing_count = df.isnull().sum()
missing_percentage = (missing_count / len(df)) * 100

missing_table = pd.DataFrame({
    'Missing Values': missing_count,
    'Percentage': missing_percentage
})

missing_table
# Out:
#                    Missing Values  Percentage
# CustomerID                      0    0.000000
# Count                           0    0.000000
# Country                         0    0.000000
# State                           0    0.000000
# City                            0    0.000000
# Zip Code                        0    0.000000
# Lat Long                        0    0.000000
# Latitude                        0    0.000000
# Longitude                       0    0.000000
# Gender                          0    0.000000
# Senior Citizen                  0    0.000000
# Partner                         0    0.000000
# Dependents                      0    0.000000
# Tenure Months                   0    0.000000
# Phone Service                   0    0.000000
# Multiple Lines                  0    0.000000
# Internet Service                0    0.000000
# Online Security                 0    0.000000
# Online Backup                   0    0.000000
# ...

# %%
missing_table[missing_table['Missing Values'] > 0]
# Out:
#               Missing Values  Percentage
# Churn Reason            5174   73.463013

# %%
df[df.isnull().any(axis=1)].head(20)
# Out:
#       CustomerID  Count        Country       State         City  Zip Code  \
# 1869  7590-VHVEG      1  United States  California  Los Angeles     90001
# 1870  5575-GNVDE      1  United States  California  Los Angeles     90002
# 1871  7795-CFOCW      1  United States  California  Los Angeles     90004
# 1872  1452-KIOVK      1  United States  California  Los Angeles     90007
# 1873  6713-OKOMC      1  United States  California  Los Angeles     90008
# 1874  6388-TABGU      1  United States  California  Los Angeles     90011
# 1875  9763-GRSKD      1  United States  California  Los Angeles     90012
# 1876  7469-LKBCI      1  United States  California  Los Angeles     90013
# 1877  8091-TTVAX      1  United States  California  Los Angeles     90014
# 1878  5129-JLPIS      1  United States  California  Los Angeles     90016
# 1879  3655-SNQYZ      1  United States  California  Los Angeles     90017
# 1880  8191-XWSZG      1  United States  California  Los Angeles     90018
# ...

# %%
pd.crosstab(
    df['Churn Label'],
    df['Churn Reason'].isnull()
)
# Out:
# Churn Reason  False  True
# Churn Label
# No                0   5174
# Yes            1869      0

# %%
df[df['Churn Reason'].isnull()]['Churn Label'].value_counts()
# Out:
# Churn Label
# No    5174
# Name: count, dtype: int64

# %%
(df == '').sum()
# Out:
# CustomerID           0
# Count                0
# Country              0
# State                0
# City                 0
# Zip Code             0
# Lat Long             0
# Latitude             0
# Longitude            0
# Gender               0
# Senior Citizen       0
# Partner              0
# Dependents           0
# Tenure Months        0
# Phone Service        0
# Multiple Lines       0
# Internet Service     0
# Online Security      0
# Online Backup        0
# Device Protection    0
# Tech Support         0
# Streaming TV         0
# Streaming Movies     0
# Contract             0
# Paperless Billing    0
# Payment Method       0
# Monthly Charges      0
# Total Charges        0
# Churn Label          0
# Churn Value          0
# Churn Score          0
# CLTV                 0
# Churn Reason         0
# dtype: int64

# %%
(df == ' ').sum()
# Out:
# CustomerID            0
# Count                 0
# Country               0
# State                 0
# City                  0
# Zip Code              0
# Lat Long              0
# Latitude              0
# Longitude             0
# Gender                0
# Senior Citizen        0
# Partner               0
# Dependents            0
# Tenure Months         0
# Phone Service         0
# Multiple Lines        0
# Internet Service      0
# Online Security       0
# Online Backup         0
# Device Protection     0
# Tech Support          0
# Streaming TV          0
# Streaming Movies      0
# Contract              0
# Paperless Billing     0
# Payment Method        0
# Monthly Charges       0
# Total Charges        11
# Churn Label           0
# Churn Value           0
# Churn Score           0
# CLTV                  0
# Churn Reason          0
# dtype: int64

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
df[df.duplicated()].head()
# Out:
# Empty DataFrame
# Columns: [CustomerID, Count, Country, State, City, Zip Code, Lat Long, Latitude, Longitude, Gender, Senior Citizen, Partner, Dependents, Tenure Months, Phone Service, Multiple Lines, Internet Service, Online Security, Online Backup, Device Protection, Tech Support, Streaming TV, Streaming Movies, Contract, Paperless Billing, Payment Method, Monthly Charges, Total Charges, Churn Label, Churn Value, Churn Score, CLTV, Churn Reason]
# Index: []
#
# [0 rows x 33 columns]

# %%
pd.crosstab(df['Churn Label'], df['Churn Reason'].isnull())
# Out:
# Churn Reason  False  True
# Churn Label
# No                0   5174
# Yes            1869      0

# %%
df[df['Churn Reason'].isnull()]['Churn Label'].value_counts()
# Out:
# Churn Label
# No    5174
# Name: count, dtype: int64

# %%
(df == '').sum()
# Out:
# CustomerID           0
# Count                0
# Country              0
# State                0
# City                 0
# Zip Code             0
# Lat Long             0
# Latitude             0
# Longitude            0
# Gender               0
# Senior Citizen       0
# Partner              0
# Dependents           0
# Tenure Months        0
# Phone Service        0
# Multiple Lines       0
# Internet Service     0
# Online Security      0
# Online Backup        0
# Device Protection    0
# Tech Support         0
# Streaming TV         0
# Streaming Movies     0
# Contract             0
# Paperless Billing    0
# Payment Method       0
# Monthly Charges      0
# Total Charges        0
# Churn Label          0
# Churn Value          0
# Churn Score          0
# CLTV                 0
# Churn Reason         0
# dtype: int64

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
print("Duplicate Customer IDs:", df['CustomerID'].duplicated().sum())
# Out:
# Duplicate Customer IDs: 0

# %%
print("Unique Customer IDs:", df['CustomerID'].nunique())
print("Total rows:", len(df))
# Out:
# Unique Customer IDs: 7043
# Total rows: 7043

# %%
df.dtypes
# Out:
# CustomerID            object
# Count                  int64
# Country               object
# State                 object
# City                  object
# Zip Code               int64
# Lat Long              object
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure Months          int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges         object
# Churn Label           object
# Churn Value            int64
# Churn Score            int64
# CLTV                   int64
# ...

# %%
df.select_dtypes(include='number').columns.tolist()
# Out:
# ['Count',
#  'Zip Code',
#  'Latitude',
#  'Longitude',
#  'Tenure Months',
#  'Monthly Charges',
#  'Churn Value',
#  'Churn Score',
#  'CLTV']

# %%
df.select_dtypes(include='object').columns.tolist()
# Out:
# ['CustomerID',
#  'Country',
#  'State',
#  'City',
#  'Lat Long',
#  'Gender',
#  'Senior Citizen',
#  'Partner',
#  'Dependents',
#  'Phone Service',
#  'Multiple Lines',
#  'Internet Service',
#  'Online Security',
#  'Online Backup',
#  'Device Protection',
#  'Tech Support',
#  'Streaming TV',
#  'Streaming Movies',
#  'Contract',
#  'Paperless Billing',
#  'Payment Method',
#  'Total Charges',
#  'Churn Label',
#  'Churn Reason']

# %%
df.describe().T
# Out:
#                   count          mean          std           min  \
# Count            7043.0      1.000000     0.000000      1.000000
# Zip Code         7043.0  93521.964646  1865.794555  90001.000000
# Latitude         7043.0     36.282441     2.455723     32.555828
# Longitude        7043.0   -119.798880     2.157889   -124.301372
# Tenure Months    7043.0     32.371149    24.559481      0.000000
# Monthly Charges  7043.0     64.761692    30.090047     18.250000
# Churn Value      7043.0      0.265370     0.441561      0.000000
# Churn Score      7043.0     58.699418    21.525131      5.000000
# CLTV             7043.0   4400.295755  1183.057152   2003.000000
#
#                           25%           50%           75%           max
# Count                1.000000      1.000000      1.000000      1.000000
# Zip Code         92102.000000  93552.000000  95351.000000  96161.000000
# Latitude            34.030915     36.391777     38.224869     41.962127
# ...

# %%
print("Duplicate Customer IDs:", df['CustomerID'].duplicated().sum())
# Out:
# Duplicate Customer IDs: 0

# %%
print("Unique Customer IDs:", df['CustomerID'].nunique())
print("Total rows:", len(df))
# Out:
# Unique Customer IDs: 7043
# Total rows: 7043

# %%
df.dtypes
# Out:
# CustomerID            object
# Count                  int64
# Country               object
# State                 object
# City                  object
# Zip Code               int64
# Lat Long              object
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure Months          int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges         object
# Churn Label           object
# Churn Value            int64
# Churn Score            int64
# CLTV                   int64
# ...

# %%
df.describe().T
# Out:
#                   count          mean          std           min  \
# Count            7043.0      1.000000     0.000000      1.000000
# Zip Code         7043.0  93521.964646  1865.794555  90001.000000
# Latitude         7043.0     36.282441     2.455723     32.555828
# Longitude        7043.0   -119.798880     2.157889   -124.301372
# Tenure Months    7043.0     32.371149    24.559481      0.000000
# Monthly Charges  7043.0     64.761692    30.090047     18.250000
# Churn Value      7043.0      0.265370     0.441561      0.000000
# Churn Score      7043.0     58.699418    21.525131      5.000000
# CLTV             7043.0   4400.295755  1183.057152   2003.000000
#
#                           25%           50%           75%           max
# Count                1.000000      1.000000      1.000000      1.000000
# Zip Code         92102.000000  93552.000000  95351.000000  96161.000000
# Latitude            34.030915     36.391777     38.224869     41.962127
# ...

# %%
print(df['Total Charges'].head(10))
# Out:
# 0     108.15
# 1     151.65
# 2      820.5
# 3    3046.05
# 4     5036.3
# 5     528.35
# 6      39.65
# 7      20.15
# 8    4749.15
# 9       30.2
# Name: Total Charges, dtype: object

# %%
print(df['Total Charges'].dtype)
# Out:
# object

# %%
pd.to_numeric(df['Total Charges'], errors='coerce').isnull().sum()
# Out:
# np.int64(11)

# %%
print(df['Count'].value_counts())
# Out:
# Count
# 1    7043
# Name: count, dtype: int64

# %%
print("Gender:")
print(df['Gender'].value_counts())
# Out:
# Gender:
# Gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
print("Senior Citizen:")
print(df['Senior Citizen'].value_counts())
# Out:
# Senior Citizen:
# Senior Citizen
# No     5901
# Yes    1142
# Name: count, dtype: int64

# %%
print("Partner:")
print(df['Partner'].value_counts())
# Out:
# Partner:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
print("Dependents:")
print(df['Dependents'].value_counts())
# Out:
# Dependents:
# Dependents
# No     5416
# Yes    1627
# Name: count, dtype: int64

# %%
for col in [
    'Phone Service',
    'Multiple Lines',
    'Internet Service',
    'Online Security',
    'Online Backup',
    'Device Protection',
    'Tech Support',
    'Streaming TV',
    'Streaming Movies'
]:
    print("\n", col)
    print(df[col].value_counts())
# Out:
#  Phone Service
# Phone Service
# Yes    6361
# No      682
# Name: count, dtype: int64
#
#  Multiple Lines
# Multiple Lines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64
#
#  Internet Service
# Internet Service
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64
#
#  Online Security
# Online Security
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: count, dtype: int64
#
#  Online Backup
# Online Backup
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: count, dtype: int64
#
#  Device Protection
# Device Protection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: count, dtype: int64
#
#  Tech Support
# Tech Support
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: count, dtype: int64
#
# ...

# %%
print(df['Total Charges'].head(10))
# Out:
# 0     108.15
# 1     151.65
# 2      820.5
# 3    3046.05
# 4     5036.3
# 5     528.35
# 6      39.65
# 7      20.15
# 8    4749.15
# 9       30.2
# Name: Total Charges, dtype: object

# %%
print(df['Total Charges'].dtype)
# Out:
# object

# %%
print(pd.to_numeric(df['Total Charges'], errors='coerce').isnull().sum())
# Out:
# 11

# %%
print(df['Count'].value_counts())
# Out:
# Count
# 1    7043
# Name: count, dtype: int64

# %%
print(df['Gender'].value_counts())
print(df['Senior Citizen'].value_counts())
print(df['Partner'].value_counts())
print(df['Dependents'].value_counts())
# Out:
# Gender
# Male      3555
# Female    3488
# Name: count, dtype: int64
# Senior Citizen
# No     5901
# Yes    1142
# Name: count, dtype: int64
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64
# Dependents
# No     5416
# Yes    1627
# Name: count, dtype: int64

# %%
print(df['Total Charges'].head(10))
# Out:
# 0     108.15
# 1     151.65
# 2      820.5
# 3    3046.05
# 4     5036.3
# 5     528.35
# 6      39.65
# 7      20.15
# 8    4749.15
# 9       30.2
# Name: Total Charges, dtype: object

# %%
print(df['Total Charges'].dtype)
# Out:
# object

# %%
print(
    pd.to_numeric(df['Total Charges'], errors='coerce').isnull().sum()
)
# Out:
# 11

# %%
print(df['Count'].value_counts())
# Out:
# Count
# 1    7043
# Name: count, dtype: int64

# %%
numeric_total = pd.to_numeric(df['Total Charges'], errors='coerce')

problematic_total = df[
    numeric_total.isnull()
][['CustomerID', 'Tenure Months', 'Monthly Charges', 'Total Charges', 'Churn Label']]

problematic_total
# Out:
#       CustomerID  Tenure Months  Monthly Charges Total Charges Churn Label
# 2234  4472-LVYGI              0            52.55                        No
# 2438  3115-CZMZD              0            20.25                        No
# 2568  5709-LVOEQ              0            80.85                        No
# 2667  4367-NUYAO              0            25.75                        No
# 2856  1371-DWPAZ              0            56.05                        No
# 4331  7644-OMVMY              0            19.85                        No
# 4687  3213-VVOLG              0            25.35                        No
# 5104  2520-SGTTA              0            20.00                        No
# 5719  2923-ARZLG              0            19.70                        No
# 6772  4075-WKNIU              0            73.35                        No
# 6840  2775-SEFEE              0            61.90                        No

# %%
for value in df.loc[numeric_total.isnull(), 'Total Charges']:
    print(repr(value))
# Out:
# ' '
# ' '
# ' '
# ' '
# ' '
# ' '
# ' '
# ' '
# ' '
# ' '
# ' '

# %%
problematic_total[['CustomerID', 'Tenure Months', 'Monthly Charges', 'Total Charges', 'Churn Label']]
# Out:
#       CustomerID  Tenure Months  Monthly Charges Total Charges Churn Label
# 2234  4472-LVYGI              0            52.55                        No
# 2438  3115-CZMZD              0            20.25                        No
# 2568  5709-LVOEQ              0            80.85                        No
# 2667  4367-NUYAO              0            25.75                        No
# 2856  1371-DWPAZ              0            56.05                        No
# 4331  7644-OMVMY              0            19.85                        No
# 4687  3213-VVOLG              0            25.35                        No
# 5104  2520-SGTTA              0            20.00                        No
# 5719  2923-ARZLG              0            19.70                        No
# 6772  4075-WKNIU              0            73.35                        No
# 6840  2775-SEFEE              0            61.90                        No

# %%
numeric_total = pd.to_numeric(df['Total Charges'], errors='coerce')

problematic_total = df[
    numeric_total.isnull()
][['CustomerID', 'Tenure Months', 'Monthly Charges', 'Total Charges', 'Churn Label']]

problematic_total
# Out:
#       CustomerID  Tenure Months  Monthly Charges  Total Charges Churn Label
# 2234  4472-LVYGI              0            52.55            NaN          No
# 2438  3115-CZMZD              0            20.25            NaN          No
# 2568  5709-LVOEQ              0            80.85            NaN          No
# 2667  4367-NUYAO              0            25.75            NaN          No
# 2856  1371-DWPAZ              0            56.05            NaN          No
# 4331  7644-OMVMY              0            19.85            NaN          No
# 4687  3213-VVOLG              0            25.35            NaN          No
# 5104  2520-SGTTA              0            20.00            NaN          No
# 5719  2923-ARZLG              0            19.70            NaN          No
# 6772  4075-WKNIU              0            73.35            NaN          No
# 6840  2775-SEFEE              0            61.90            NaN          No

# %%
for value in df.loc[numeric_total.isnull(), 'Total Charges']:
    print(repr(value))
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
df['Total Charges'] = pd.to_numeric(
    df['Total Charges'],
    errors='coerce'
)

# %%
print(df['Total Charges'].dtype)
# Out:
# float64

# %%
print("Missing Total Charges:", df['Total Charges'].isnull().sum())
# Out:
# Missing Total Charges: 11

# %%
df['Total Charges'] = df['Total Charges'].fillna(0)

# %%
print("Missing Total Charges:", df['Total Charges'].isnull().sum())
# Out:
# Missing Total Charges: 0

# %%
print(df['Total Charges'].dtype)
# Out:
# float64

# %%
print("Unique values in Count:", df['Count'].nunique())
print("Standard deviation:", df['Count'].std())
# Out:
# Unique values in Count: 1
# Standard deviation: 0.0

# %%
numeric_cols = [
    'Tenure Months',
    'Monthly Charges',
    'Total Charges',
    'Churn Score',
    'CLTV'
]

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[
        (df[col] < lower_bound) |
        (df[col] > upper_bound)
    ]

    print(f"\n{col}")
    print("Q1:", Q1)
    print("Q3:", Q3)
    print("IQR:", IQR)
    print("Lower Bound:", lower_bound)
    print("Upper Bound:", upper_bound)
    print("Number of outliers:", len(outliers))
# Out:
# Tenure Months
# Q1: 9.0
# Q3: 55.0
# IQR: 46.0
# Lower Bound: -60.0
# Upper Bound: 124.0
# Number of outliers: 0
#
# Monthly Charges
# Q1: 35.5
# Q3: 89.85
# IQR: 54.349999999999994
# Lower Bound: -46.02499999999999
# Upper Bound: 171.375
# Number of outliers: 0
#
# Total Charges
# Q1: 398.55
# Q3: 3786.6
# IQR: 3388.0499999999997
# Lower Bound: -4683.525
# Upper Bound: 8868.675
# Number of outliers: 0
#
# Churn Score
# Q1: 40.0
# Q3: 75.0
# IQR: 35.0
# Lower Bound: -12.5
# Upper Bound: 127.5
# Number of outliers: 0
#
# CLTV
# Q1: 3469.0
# Q3: 5380.5
# IQR: 1911.5
# Lower Bound: 601.75
# Upper Bound: 8247.75
# Number of outliers: 0

# %%
categorical_cols = [
    'Phone Service',
    'Multiple Lines',
    'Internet Service',
    'Online Security',
    'Online Backup',
    'Device Protection',
    'Tech Support',
    'Streaming TV',
    'Streaming Movies',
    'Contract',
    'Paperless Billing',
    'Payment Method',
    'Churn Label'
]

for col in categorical_cols:
    print("\n" + "=" * 50)
    print(col)
    print(df[col].value_counts())
# Out:
# ...
# Phone Service
# Phone Service
# Yes    6361
# No      682
# Name: count, dtype: int64
#
# ...
# Multiple Lines
# Multiple Lines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64
#
# ...
# Internet Service
# Internet Service
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64
#
# ...
# Online Security
# Online Security
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: count, dtype: int64
#
# ...
# Online Backup
# Online Backup
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: count, dtype: int64
#
# ...
# Device Protection
# Device Protection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: count, dtype: int64
#
# ...
# Tech Support
# Tech Support
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: count, dtype: int64
#
# ...

# %%
print("Total rows:", len(df))
print("Unique Customer IDs:", df['CustomerID'].nunique())
print("Duplicate Customer IDs:", df['CustomerID'].duplicated().sum())
# Out:
# Total rows: 7043
# Unique Customer IDs: 7043
# Duplicate Customer IDs: 0

# %%
print("Negative Tenure:", (df['Tenure Months'] < 0).sum())
print("Negative Monthly Charges:", (df['Monthly Charges'] < 0).sum())
print("Negative Total Charges:", (df['Total Charges'] < 0).sum())
print("Invalid Churn Value:", (~df['Churn Value'].isin([0, 1])).sum())
print("Invalid Churn Score:", ((df['Churn Score'] < 0) | (df['Churn Score'] > 100)).sum())
print("Negative CLTV:", (df['CLTV'] < 0).sum())
# Out:
# Negative Tenure: 0
# Negative Monthly Charges: 0
# Negative Total Charges: 0
# Invalid Churn Value: 0
# Invalid Churn Score: 0
# Negative CLTV: 0

# %%
print(
    pd.crosstab(
        df['Churn Label'],
        df['Churn Value']
    )
)
# Out:
# Churn Value     0     1
# Churn Label
# No           5174     0
# Yes             0  1869

# %%
print("Total rows:", len(df))
print("Unique Customer IDs:", df['CustomerID'].nunique())
print("Duplicate Customer IDs:", df['CustomerID'].duplicated().sum())
# Out:
# Total rows: 7043
# Unique Customer IDs: 7043
# Duplicate Customer IDs: 0

# %%
print("Negative Tenure:", (df['Tenure Months'] < 0).sum())
print("Negative Monthly Charges:", (df['Monthly Charges'] < 0).sum())
print("Negative Total Charges:", (df['Total Charges'] < 0).sum())
print("Invalid Churn Value:", (~df['Churn Value'].isin([0, 1])).sum())
print("Invalid Churn Score:", ((df['Churn Score'] < 0) | (df['Churn Score'] > 100)).sum())
print("Negative CLTV:", (df['CLTV'] < 0).sum())
# Out:
# Negative Tenure: 0
# Negative Monthly Charges: 0
# Negative Total Charges: 0
# Invalid Churn Value: 0
# Invalid Churn Score: 0
# Negative CLTV: 0

# %%
df = df.drop(columns=['Count'])

# %%
print(df.shape)
print('Count' in df.columns)
# Out:
# (7043, 32)
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Country            7043 non-null   object
#  2   State              7043 non-null   object
#  3   City               7043 non-null   object
#  4   Zip Code           7043 non-null   int64
#  5   Lat Long           7043 non-null   object
#  6   Latitude           7043 non-null   float64
#  7   Longitude          7043 non-null   float64
#  8   Gender             7043 non-null   object
#  9   Senior Citizen     7043 non-null   object
#  10  Partner            7043 non-null   object
#  11  Dependents         7043 non-null   object
#  12  Tenure Months      7043 non-null   int64
#  13  Phone Service      7043 non-null   object
#  14  Multiple Lines     7043 non-null   object
#  15  Internet Service   7043 non-null   object
# ...

# %%
print("Total missing values:", df.isnull().sum().sum())
print("Total duplicate rows:", df.duplicated().sum())
# Out:
# Total missing values: 5174
# Total duplicate rows: 0

# %%
print(df['Total Charges'].describe())
# Out:
# count    7043.000000
# mean     2279.734304
# std      2266.794470
# min         0.000000
# 25%       398.550000
# 50%      1394.550000
# 75%      3786.600000
# max      8684.800000
# Name: Total Charges, dtype: float64

# %%
print(df['Total Charges'].isnull().sum())
# Out:
# 0

# %%
print(df.columns.tolist())
# Out:
# ['CustomerID', 'Country', 'State', 'City', 'Zip Code', 'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Tenure Months', 'Phone Service', 'Multiple Lines', 'Internet Service', 'Online Security', 'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value', 'Churn Score', 'CLTV', 'Churn Reason']

# %%
df = df.drop(columns=[
    'CustomerID',
    'Country',
    'State',
    'Lat Long'
])

# %%
print(df.shape)
print(df.columns.tolist())
# Out:
# (7043, 28)
# ['City', 'Zip Code', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Tenure Months', 'Phone Service', 'Multiple Lines', 'Internet Service', 'Online Security', 'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value', 'Churn Score', 'CLTV', 'Churn Reason']

# %%
cleaned_df = df.copy()

print("Cleaned dataset shape:", cleaned_df.shape)
# Out:
# Cleaned dataset shape: (7043, 28)

# %%
model_df = cleaned_df.drop(columns=['Churn Label', 'Churn Reason'])

# %%
print(model_df.shape)
print(model_df.columns.tolist())
# Out:
# (7043, 26)
# ['City', 'Zip Code', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Tenure Months', 'Phone Service', 'Multiple Lines', 'Internet Service', 'Online Security', 'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn Value', 'Churn Score', 'CLTV']

# %%
categorical_cols = model_df.select_dtypes(include='object').columns.tolist()

print("Categorical columns:")
print(categorical_cols)
# Out:
# Categorical columns:
# ['City', 'Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Phone Service', 'Multiple Lines', 'Internet Service', 'Online Security', 'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method']

# %%
model_df_encoded = pd.get_dummies(
    model_df,
    columns=categorical_cols,
    drop_first=True
)

# %%
print("Before encoding:", model_df.shape)
print("After encoding:", model_df_encoded.shape)
# Out:
# Before encoding: (7043, 26)
# After encoding: (7043, 1164)

# %%
model_df_encoded = model_df_encoded.astype(int)

# %%
print(model_df_encoded.dtypes.value_counts())
# Out:
# int64    1164
# Name: count, dtype: int64

# %%
print("Object columns remaining:",
      model_df_encoded.select_dtypes(include='object').columns.tolist())
# Out:
# Object columns remaining: []

# %%
print(model_df_encoded.head())
# Out:
#    Zip Code  Latitude  Longitude  Tenure Months  Monthly Charges  \
# 0     90003        33       -118              2               53
# 1     90005        34       -118              2               70
# 2     90006        34       -118              8               99
# 3     90010        34       -118             28              104
# 4     90015        34       -118             49              103
#
#    Total Charges  Churn Value  Churn Score  CLTV  City_Acton  ...  \
# 0            108            1           86  3239           0  ...
# 1            151            1           67  2701           0  ...
# 2            820            1           86  5372           0  ...
# 3           3046            1           84  5003           0  ...
# 4           5036            1           89  5340           0  ...
#
#    Streaming TV_No internet service  Streaming TV_Yes  \
# 0                                 0                 0
# 1                                 0                 0
# ...

# %%
print(model_df_encoded.shape)
# Out:
# (7043, 1164)

# %%
print("Total missing values:",
      model_df_encoded.isnull().sum().sum())
# Out:
# Total missing values: 0

# %%
print("Duplicate rows:",
      model_df_encoded.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
print(model_df_encoded.dtypes.value_counts())
# Out:
# int64    1164
# Name: count, dtype: int64

# %%
print("Object columns:",
      model_df_encoded.select_dtypes(include='object').columns.tolist())
# Out:
# Object columns: []

# %%
print("Churn Value" in model_df_encoded.columns)
# Out:
# True

# %%
print(model_df_encoded.describe().T.head(20))
# Out:
#                     count          mean          std      min      25%  \
# Zip Code           7043.0  93521.964646  1865.794555  90001.0  92102.0
# Latitude           7043.0     35.775096     2.469345     32.0     34.0
# Longitude          7043.0   -119.338918     2.158186   -124.0   -121.0
# Tenure Months      7043.0     32.371149    24.559481      0.0      9.0
# Monthly Charges    7043.0     64.295897    30.092727     18.0     35.0
# Total Charges      7043.0   2279.265086  2266.790864      0.0    398.0
# Churn Value        7043.0      0.265370     0.441561      0.0      0.0
# Churn Score        7043.0     58.699418    21.525131      5.0     40.0
# CLTV               7043.0   4400.295755  1183.057152   2003.0   3469.0
# City_Acton         7043.0      0.000568     0.023826      0.0      0.0
# City_Adelanto      7043.0      0.000710     0.026637      0.0      0.0
# City_Adin          7043.0      0.000568     0.023826      0.0      0.0
# ...

# %%
print("Shape:", model_df_encoded.shape)

print("Missing values:",
      model_df_encoded.isnull().sum().sum())

print("Duplicate rows:",
      model_df_encoded.duplicated().sum())

print("Object columns:",
      model_df_encoded.select_dtypes(include='object').columns.tolist())

print("Infinite values:",
      np.isinf(model_df_encoded.select_dtypes(include=np.number)).sum().sum())
# Out:
# Shape: (7043, 1164)
# Missing values: 0
# Duplicate rows: 0
# Object columns: []
# Infinite values: 0

# %%
cleaned_df.to_csv('/content/telco_churn_cleaned.csv', index=False)

# %%
model_df_encoded.to_csv('/content/telco_churn_preprocessed.csv', index=False)

# %%
import os

print("Cleaned file exists:",
      os.path.exists('/content/telco_churn_cleaned.csv'))

print("Preprocessed file exists:",
      os.path.exists('/content/telco_churn_preprocessed.csv'))
# Out:
# Cleaned file exists: True
# Preprocessed file exists: True

# %%
print("========== BEFORE CLEANING ==========")
print("Rows:", 7043)
print("Columns:", 33)

print("\n========== AFTER CLEANING ==========")
print("Rows:", cleaned_df.shape[0])
print("Columns:", cleaned_df.shape[1])

print("\n========== AFTER ENCODING ==========")
print("Rows:", model_df_encoded.shape[0])
print("Columns:", model_df_encoded.shape[1])
# Out:
# ========== BEFORE CLEANING ==========
# Rows: 7043
# Columns: 33
#
# ========== AFTER CLEANING ==========
# Rows: 7043
# Columns: 28
#
# ========== AFTER ENCODING ==========
# Rows: 7043
# Columns: 1164

# %%
print(df.shape)
# Out:
# (7043, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               7043 non-null   object
#  1   Zip Code           7043 non-null   int64
#  2   Latitude           7043 non-null   float64
#  3   Longitude          7043 non-null   float64
#  4   Gender             7043 non-null   object
#  5   Senior Citizen     7043 non-null   object
#  6   Partner            7043 non-null   object
#  7   Dependents         7043 non-null   object
#  8   Tenure Months      7043 non-null   int64
#  9   Phone Service      7043 non-null   object
#  10  Multiple Lines     7043 non-null   object
#  11  Internet Service   7043 non-null   object
#  12  Online Security    7043 non-null   object
#  13  Online Backup      7043 non-null   object
#  14  Device Protection  7043 non-null   object
#  15  Tech Support       7043 non-null   object
# ...

# %%
missing_table = pd.DataFrame({
    'Missing Values': df.isnull().sum(),
    'Percentage': (df.isnull().sum() / len(df)) * 100
})

missing_table
# Out:
#                    Missing Values  Percentage
# City                            0    0.000000
# Zip Code                        0    0.000000
# Latitude                        0    0.000000
# Longitude                       0    0.000000
# Gender                          0    0.000000
# Senior Citizen                  0    0.000000
# Partner                         0    0.000000
# Dependents                      0    0.000000
# Tenure Months                   0    0.000000
# Phone Service                   0    0.000000
# Multiple Lines                  0    0.000000
# Internet Service                0    0.000000
# Online Security                 0    0.000000
# Online Backup                   0    0.000000
# Device Protection               0    0.000000
# Tech Support                    0    0.000000
# Streaming TV                    0    0.000000
# Streaming Movies                0    0.000000
# Contract                        0    0.000000
# ...

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
print(df['Gender'].value_counts())
# Out:
# Gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
print(df['Contract'].value_counts())
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
pd.crosstab(df['Churn Label'], df['Churn Value'])
# Out:
# Churn Value     0     1
# Churn Label
# No           5174     0
# Yes             0  1869

# %%
df['Total Charges'] = pd.to_numeric(
    df['Total Charges'],
    errors='coerce'
)

# %%
categorical_cols = model_df.select_dtypes(
    include='object'
).columns.tolist()

model_df_encoded = pd.get_dummies(
    model_df,
    columns=categorical_cols,
    drop_first=True
)

model_df_encoded = model_df_encoded.astype(int)

# %%
print("Shape:", model_df_encoded.shape)

print(
    "Missing values:",
    model_df_encoded.isnull().sum().sum()
)

print(
    "Duplicate rows:",
    model_df_encoded.duplicated().sum()
)

print(
    "Object columns:",
    model_df_encoded.select_dtypes(
        include='object'
    ).columns.tolist()
)
# Out:
# Shape: (7043, 1164)
# Missing values: 0
# Duplicate rows: 0
# Object columns: []
