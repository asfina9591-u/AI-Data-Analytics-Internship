# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

import warnings
warnings.filterwarnings("ignore")

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df = pd.read_csv("../data/Mall_Customers.csv")

print("Dataset loaded successfully!")
print("Shape:", df.shape)

df.head()
# Out:
# Dataset loaded successfully!
# Shape: (200, 5)
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
print("Dataset Information:")
print(df.info())

print("\nMissing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())

print("\nStatistical Summary:")
display(df.describe())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None
#
# Missing Values:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64
#
# Duplicate Rows:
# 0
#
# Statistical Summary:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# ...

# %%
print(df.columns.tolist())
# Out:
# ['CustomerID', 'Genre', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']

# %%
features = [
    "Age",
    "Annual Income (k$)",
    "Spending Score (1-100)"
]

X = df[features]

print("Selected features:")
display(X.head())
# Out:
# Selected features:
#    Age  Annual Income (k$)  Spending Score (1-100)
# 0   19                  15                      39
# 1   21                  15                      81
# 2   20                  16                       6
# 3   23                  16                      77
# 4   31                  17                      40

# %%
plt.figure(figsize=(8, 5))

sns.histplot(df["Age"], kde=True)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Number of Customers")

plt.savefig("../outputs/age_distribution.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.histplot(df["Annual Income (k$)"], kde=True)

plt.title("Annual Income Distribution")
plt.xlabel("Annual Income (k$)")
plt.ylabel("Number of Customers")

plt.savefig("../outputs/income_distribution.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.histplot(df["Spending Score (1-100)"], kde=True)

plt.title("Spending Score Distribution")
plt.xlabel("Spending Score")
plt.ylabel("Number of Customers")

plt.savefig("../outputs/spending_score_distribution.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
features = [
    "Age",
    "Annual Income (k$)",
    "Spending Score (1-100)"
]

X = df[features]

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

print("Data standardized successfully!")
print("Shape:", X_scaled.shape)
# Out:
# Data standardized successfully!
# Shape: (200, 3)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

inertia = []
silhouette_scores = []

K_range = range(2, 9)

for k in K_range:

    kmeans = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )

    labels = kmeans.fit_predict(X_scaled)

    inertia.append(kmeans.inertia_)

    silhouette_scores.append(
        silhouette_score(X_scaled, labels)
    )

print("K values:", list(K_range))
print("Inertia:", inertia)
print("Silhouette Scores:", silhouette_scores)
# Out:
# K values: [2, 3, 4, 5, 6, 7, 8]
# Inertia: [389.3861889564372, 295.2122461555489, 205.22514747675913, 168.24758017556837, 133.86842085478855, 117.01155455889813, 103.87329152383714]
# Silhouette Scores: [0.33547192894004574, 0.357793388710272, 0.4039582785148566, 0.41664341513732767, 0.4284167762892593, 0.417231894954916, 0.4082067042807375]

# %%
import pandas as pd

df = pd.read_csv("../data/Mall_Customers.csv")

print(df.shape)
df.head()
# Out:
# (200, 5)
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
features = [
    "Age",
    "Annual Income (k$)",
    "Spending Score (1-100)"
]

X = df[features]

print("Selected features:")
display(X.head())

print("\nShape:", X.shape)
# Out:
# Selected features:
#    Age  Annual Income (k$)  Spending Score (1-100)
# 0   19                  15                      39
# 1   21                  15                      81
# 2   20                  16                       6
# 3   23                  16                      77
# 4   31                  17                      40
# Shape: (200, 3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

import warnings
warnings.filterwarnings("ignore")

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
df = pd.read_csv("../data/Mall_Customers.csv")

print("Dataset loaded successfully!")
print("Dataset shape:", df.shape)

display(df.head())
# Out:
# Dataset loaded successfully!
# Dataset shape: (200, 5)
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
print("Dataset Information:")
df.info()

print("\nMissing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())

print("\nStatistical Summary:")
display(df.describe())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
#
# Missing Values:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64
#
# Duplicate Rows:
# 0
#
# Statistical Summary:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# ...

# %%
features = [
    "Age",
    "Annual Income (k$)",
    "Spending Score (1-100)"
]

X = df[features]

print("Selected clustering features:")
display(X.head())

print("\nFeature matrix shape:", X.shape)
# Out:
# Selected clustering features:
#    Age  Annual Income (k$)  Spending Score (1-100)
# 0   19                  15                      39
# 1   21                  15                      81
# 2   20                  16                       6
# 3   23                  16                      77
# 4   31                  17                      40
# Feature matrix shape: (200, 3)

# %%
plt.figure(figsize=(8, 5))

sns.histplot(
    df["Age"],
    kde=True
)

plt.title("Age Distribution of Customers")
plt.xlabel("Age")
plt.ylabel("Number of Customers")

plt.savefig(
    "../outputs/age_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.histplot(
    df["Annual Income (k$)"],
    kde=True
)

plt.title("Annual Income Distribution")
plt.xlabel("Annual Income (k$)")
plt.ylabel("Number of Customers")

plt.savefig(
    "../outputs/income_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.histplot(
    df["Spending Score (1-100)"],
    kde=True
)

plt.title("Spending Score Distribution")
plt.xlabel("Spending Score")
plt.ylabel("Number of Customers")

plt.savefig(
    "../outputs/spending_score_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

X_scaled = pd.DataFrame(
    X_scaled,
    columns=features
)

print("Standardization completed successfully!")

display(X_scaled.head())

print("\nScaled data shape:", X_scaled.shape)
# Out:
# Standardization completed successfully!
#         Age  Annual Income (k$)  Spending Score (1-100)
# 0 -1.424569           -1.738999               -0.434801
# 1 -1.281035           -1.738999                1.195704
# 2 -1.352802           -1.700830               -1.715913
# 3 -1.137502           -1.700830                1.040418
# 4 -0.563369           -1.662660               -0.395980
# Scaled data shape: (200, 3)

# %%
inertia = []
silhouette_scores = []

K_range = range(2, 9)

for k in K_range:

    kmeans = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )

    labels = kmeans.fit_predict(X_scaled)

    inertia.append(kmeans.inertia_)

    silhouette_scores.append(
        silhouette_score(X_scaled, labels)
    )

print("K values:", list(K_range))
print("Inertia:", inertia)
print("Silhouette Scores:", silhouette_scores)
# Out:
# K values: [2, 3, 4, 5, 6, 7, 8]
# Inertia: [389.3861889564372, 295.2122461555489, 205.22514747675913, 168.24758017556837, 133.86842085478855, 117.01155455889813, 103.87329152383714]
# Silhouette Scores: [0.33547192894004574, 0.357793388710272, 0.4039582785148566, 0.41664341513732767, 0.4284167762892593, 0.417231894954916, 0.4082067042807375]

# %%
plt.figure(figsize=(8, 5))

plt.plot(
    list(K_range),
    inertia,
    marker="o"
)

plt.title("Elbow Method for Optimal Number of Clusters")
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Inertia")

plt.grid(True)

plt.savefig(
    "../outputs/elbow_curve.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.plot(
    list(K_range),
    silhouette_scores,
    marker="o"
)

plt.title("Silhouette Score for Different Cluster Numbers")
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Silhouette Score")

plt.grid(True)

plt.savefig(
    "../outputs/silhouette_scores.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
best_k = list(K_range)[np.argmax(silhouette_scores)]

best_score = max(silhouette_scores)

print("Best K based on Silhouette Score:", best_k)
print("Best Silhouette Score:", round(best_score, 4))
# Out:
# Best K based on Silhouette Score: 6
# Best Silhouette Score: 0.4284

# %%
optimal_k = best_k

kmeans = KMeans(
    n_clusters=optimal_k,
    random_state=42,
    n_init=10
)

df["Cluster"] = kmeans.fit_predict(X_scaled)

print("Final K-Means clustering completed!")
print("Number of clusters:", optimal_k)

print("\nCustomers in each cluster:")
print(
    df["Cluster"]
    .value_counts()
    .sort_index()
)
# Out:
# Final K-Means clustering completed!
# Number of clusters: 6
#
# Customers in each cluster:
# Cluster
# 0    45
# 1    39
# 2    33
# 3    39
# 4    23
# 5    21
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x="Cluster"
)

plt.title("Number of Customers in Each Cluster")
plt.xlabel("Cluster")
plt.ylabel("Number of Customers")

plt.savefig(
    "../outputs/cluster_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(9, 6))

sns.scatterplot(
    data=df,
    x="Annual Income (k$)",
    y="Spending Score (1-100)",
    hue="Cluster",
    palette="Set2",
    s=80
)

plt.title(
    "Customer Segmentation by Annual Income and Spending Score"
)

plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score (1-100)")

plt.legend(title="Cluster")

plt.savefig(
    "../outputs/income_vs_spending_clusters.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
plt.figure(figsize=(9, 6))

sns.scatterplot(
    data=df,
    x="Age",
    y="Spending Score (1-100)",
    hue="Cluster",
    palette="Set2",
    s=80
)

plt.title(
    "Customer Segmentation by Age and Spending Score"
)

plt.xlabel("Age")
plt.ylabel("Spending Score (1-100)")

plt.legend(title="Cluster")

plt.savefig(
    "../outputs/age_vs_spending_clusters.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 7))

ax = fig.add_subplot(
    111,
    projection="3d"
)

scatter = ax.scatter(
    df["Age"],
    df["Annual Income (k$)"],
    df["Spending Score (1-100)"],
    c=df["Cluster"],
    s=60
)

ax.set_xlabel("Age")
ax.set_ylabel("Annual Income (k$)")
ax.set_zlabel("Spending Score (1-100)")

ax.set_title(
    "3D Visualization of Customer Clusters"
)

plt.savefig(
    "../outputs/clusters_3d.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
cluster_profile = df.groupby("Cluster")[features].mean().round(2)

print("Average Characteristics of Each Cluster:")

display(cluster_profile)
# Out:
# Average Characteristics of Each Cluster:
#            Age  Annual Income (k$)  Spending Score (1-100)
# Cluster
# 0        56.33               54.27                   49.07
# 1        26.79               57.10                   48.13
# 2        41.94               88.94                   16.97
# 3        32.69               86.54                   82.13
# 4        25.00               25.26                   77.61
# 5        45.52               26.29                   19.38

# %%
genre_cluster = pd.crosstab(
    df["Cluster"],
    df["Genre"]
)

print("Genre Distribution Across Clusters:")

display(genre_cluster)
# Out:
# Genre Distribution Across Clusters:
# Genre    Female  Male
# Cluster
# 0            26    19
# 1            25    14
# 2            14    19
# 3            21    18
# 4            13    10
# 5            13     8

# %%
genre_cluster.plot(
    kind="bar",
    figsize=(9, 6)
)

plt.title("Genre Distribution Across Customer Clusters")
plt.xlabel("Cluster")
plt.ylabel("Number of Customers")

plt.xticks(rotation=0)

plt.tight_layout()

plt.savefig(
    "../outputs/genre_cluster_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
cluster_summary = df.groupby("Cluster").agg(
    Customers=("CustomerID", "count"),
    Average_Age=("Age", "mean"),
    Average_Income=("Annual Income (k$)", "mean"),
    Average_Spending=("Spending Score (1-100)", "mean")
).round(2)

print("Final Cluster Summary:")

display(cluster_summary)
# Out:
# Final Cluster Summary:
#          Customers  Average_Age  Average_Income  Average_Spending
# Cluster
# 0               45        56.33           54.27             49.07
# 1               39        26.79           57.10             48.13
# 2               33        41.94           88.94             16.97
# 3               39        32.69           86.54             82.13
# 4               23        25.00           25.26             77.61
# 5               21        45.52           26.29             19.38

# %%
cluster_summary.to_csv(
    "../outputs/cluster_summary.csv"
)

print("Cluster summary saved successfully!")
# Out:
# Cluster summary saved successfully!

# %%
df.to_csv(
    "../outputs/customer_clusters.csv",
    index=False
)

print("Final clustered dataset saved successfully!")
print("Shape:", df.shape)
# Out:
# Final clustered dataset saved successfully!
# Shape: (200, 6)

# %%
print("=" * 60)
print("WEEK 3 CLUSTERING ANALYSIS - FINAL SUMMARY")
print("=" * 60)

print("\nDataset:")
print("Total Customers:", len(df))

print("\nFeatures Used:")
for feature in features:
    print("-", feature)

print("\nOptimal Number of Clusters:", optimal_k)

print(
    "Silhouette Score:",
    round(best_score, 4)
)

print("\nCluster Sizes:")
print(
    df["Cluster"]
    .value_counts()
    .sort_index()
)

print("\nCluster Profiles:")
display(cluster_profile)

print("=" * 60)
print("Analysis completed successfully!")
print("=" * 60)
# Out:
# ...
# WEEK 3 CLUSTERING ANALYSIS - FINAL SUMMARY
# ...
#
# Dataset:
# Total Customers: 200
#
# Features Used:
# - Age
# - Annual Income (k$)
# - Spending Score (1-100)
#
# Optimal Number of Clusters: 6
# Silhouette Score: 0.4284
#
# Cluster Sizes:
# Cluster
# 0    45
# 1    39
# 2    33
# 3    39
# 4    23
# 5    21
# Name: count, dtype: int64
#
# Cluster Profiles:
#            Age  Annual Income (k$)  Spending Score (1-100)
# Cluster
# 0        56.33               54.27                   49.07
# 1        26.79               57.10                   48.13
# 2        41.94               88.94                   16.97
# 3        32.69               86.54                   82.13
# 4        25.00               25.26                   77.61
# 5        45.52               26.29                   19.38
# ...
# Analysis completed successfully!
# ...

# %%
print("=" * 70)
print("DETAILED CLUSTER PROFILE")
print("=" * 70)

cluster_profile = df.groupby("Cluster").agg(
    Customers=("CustomerID", "count"),
    Average_Age=("Age", "mean"),
    Average_Income=("Annual Income (k$)", "mean"),
    Average_Spending=("Spending Score (1-100)", "mean")
).round(2)

display(cluster_profile)
# Out:
# ...
# DETAILED CLUSTER PROFILE
# ...
#          Customers  Average_Age  Average_Income  Average_Spending
# Cluster
# 0               45        56.33           54.27             49.07
# 1               39        26.79           57.10             48.13
# 2               33        41.94           88.94             16.97
# 3               39        32.69           86.54             82.13
# 4               23        25.00           25.26             77.61
# 5               21        45.52           26.29             19.38

# %%
print("=" * 70)
print("DETAILED CLUSTER PROFILE")
print("=" * 70)

cluster_profile = df.groupby("Cluster").agg(
    Customers=("CustomerID", "count"),
    Average_Age=("Age", "mean"),
    Average_Income=("Annual Income (k$)", "mean"),
    Average_Spending=("Spending Score (1-100)", "mean")
).round(2)

display(cluster_profile)
# Out:
# ...
# DETAILED CLUSTER PROFILE
# ...
#          Customers  Average_Age  Average_Income  Average_Spending
# Cluster
# 0               45        56.33           54.27             49.07
# 1               39        26.79           57.10             48.13
# 2               33        41.94           88.94             16.97
# 3               39        32.69           86.54             82.13
# 4               23        25.00           25.26             77.61
# 5               21        45.52           26.29             19.38

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=cluster_profile,
    x="Average_Income",
    y="Average_Spending",
    hue=cluster_profile.index,
    palette="Set2",
    s=250
)

for cluster in cluster_profile.index:
    plt.annotate(
        f"Cluster {cluster}",
        (
            cluster_profile.loc[cluster, "Average_Income"],
            cluster_profile.loc[cluster, "Average_Spending"]
        ),
        xytext=(8, 8),
        textcoords="offset points"
    )

plt.title("Cluster Comparison: Average Income vs Average Spending")
plt.xlabel("Average Annual Income (k$)")
plt.ylabel("Average Spending Score")
plt.grid(True)

plt.savefig(
    "../outputs/cluster_business_comparison.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
cluster_profile.to_csv(
    "../outputs/final_cluster_profile.csv"
)

print("Final cluster profile saved successfully!")
# Out:
# Final cluster profile saved successfully!
